# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, callbacks
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt


gpus = tf.config.list_physical_devices('GPU')
if gpus:
    tf.config.experimental.set_memory_growth(gpus[0], True)
    print("✅ Using GPU:", gpus[0])
else:
    print("⚠️ No GPU found — running on CPU")

df = pd.read_csv("/content/train_data.csv")

def parse_embedding(emb_str):
    return np.array([float(x) for x in emb_str.split(",")], dtype=np.float32)

df["word_embedding"] = df["word_embedding"].apply(parse_embedding)
df["audio_embedding"] = df["audio_embedding"].apply(parse_embedding)

X_text = np.stack(df["word_embedding"].values)
X_audio = np.stack(df["audio_embedding"].values)
y = df["y"].values

print("✅ Text shape:", X_text.shape)
print("✅ Audio shape:", X_audio.shape)

# Split dataset
X_text_train, X_text_test, X_audio_train, X_audio_test, y_train, y_test = train_test_split(
    X_text, X_audio, y, test_size=0.2, random_state=42, stratify=y
)

# Expand dims for Conv/LSTM input
X_text_train = np.expand_dims(X_text_train, 1)
X_audio_train = np.expand_dims(X_audio_train, 1)
X_text_test = np.expand_dims(X_text_test, 1)
X_audio_test = np.expand_dims(X_audio_test, 1)


def text_branch(input_shape):
    inp = layers.Input(shape=input_shape)
    x = layers.Conv1D(256, 1, activation='relu')(inp)
    x = layers.Conv1D(128, 1, activation='relu')(x)
    x = layers.Bidirectional(layers.GRU(128, return_sequences=True))(x)
    x = layers.MultiHeadAttention(num_heads=4, key_dim=64)(x, x)
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dense(256, activation='relu')(x)
    x = layers.Dropout(0.3)(x)
    return models.Model(inp, x, name="TextBranch")

def audio_branch(input_shape):
    inp = layers.Input(shape=input_shape)
    x = layers.Conv1D(256, 1, activation='relu')(inp)
    x = layers.Conv1D(128, 3, padding='same', activation='relu')(x)
    x = layers.Bidirectional(layers.LSTM(128, return_sequences=True))(x)
    x = layers.MultiHeadAttention(num_heads=4, key_dim=64)(x, x)
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dense(256, activation='relu')(x)
    x = layers.Dropout(0.3)(x)
    return models.Model(inp, x, name="AudioBranch")

# Create branches
text_inp_shape = (X_text_train.shape[1], X_text_train.shape[2])
audio_inp_shape = (X_audio_train.shape[1], X_audio_train.shape[2])

text_model = text_branch(text_inp_shape)
audio_model = audio_branch(audio_inp_shape)


combined = layers.Concatenate()([text_model.output, audio_model.output])
x = layers.Dense(256, activation='relu')(combined)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.4)(x)
x = layers.Dense(128, activation='relu')(x)
x = layers.Dropout(0.3)(x)
x = layers.Dense(64, activation='relu')(x)
out = layers.Dense(7, activation='softmax')(x)

model = models.Model(inputs=[text_model.input, audio_model.input], outputs=out)
model.summary()


model.compile(
    optimizer=optimizers.Adam(learning_rate=1e-4),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

callbacks_list = [
    callbacks.EarlyStopping(monitor="val_loss", patience=6, restore_best_weights=True),
    callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=3, verbose=1)
]

history = model.fit(
    [X_text_train, X_audio_train], y_train,
    validation_data=([X_text_test, X_audio_test], y_test),
    epochs=50,
    batch_size=32,
    callbacks=callbacks_list,
    verbose=1
)


loss, acc = model.evaluate([X_text_test, X_audio_test], y_test)
print(f"\n✅ Test Accuracy: {acc:.4f}")

model.save("/content/final_multimodal_emotion_model_v99.h5")
print("✅ Model saved successfully!")


plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(history.history["accuracy"], label="Train Acc")
plt.plot(history.history["val_accuracy"], label="Val Acc")
plt.legend(); plt.title("Accuracy")

plt.subplot(1,2,2)
plt.plot(history.history["loss"], label="Train Loss")
plt.plot(history.history["val_loss"], label="Val Loss")
plt.legend(); plt.title("Loss")
plt.show()
# Out:
# ✅ Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# ✅ Text shape: (12598, 768)
# ✅ Audio shape: (12598, 768)
# Model: "functional_30"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_9       │ (None, 1, 768)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_10      │ (None, 1, 768)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_22 (Conv1D)  │ (None, 1, 256)    │    196,864 │ input_layer_9[0]… │
# ...

# %%
train_acc = history.history['accuracy'][-1]
val_acc = history.history['val_accuracy'][-1]

print(f"\n Final Training Accuracy: {train_acc:.4f}")

test_loss, test_acc = model.evaluate([X_text_test, X_audio_test], y_test, verbose=0)
print(f"\n Test Accuracy: {test_acc:.4f}")
# Out:
#  Final Training Accuracy: 0.7599
#
#  Test Accuracy: 0.6206
